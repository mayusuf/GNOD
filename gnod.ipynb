# %% [markdown]
# ## Lab | Web Scraping Single Page (GNOD part 1)
# Business goal:
# Check the case_study_gnod.md file.
#
# Make sure you've understood the big picture of your project:
#
# the goal of the company (Gnod),
# their current product (Gnoosic),
# their strategy, and
# how your project fits into this context.
# Re-read the business case and the e-mail from the CTO.
#
# Instructions - Scraping popular songs
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will also enjoy a recommendation of another song that is popular at the moment.
#
# You have to find data on the internet about currently popular songs. Popvortex maintains a weekly Top 100 of "hot" songs here: http://www.popvortex.com/music/charts/top-100-songs.php.
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from pandas import json_normalize
pd.set_option("display.max_columns", 0)

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3.0 download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1 parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
# soup

# %%
board_positions = soup.select(".cover-art.col-xs-12.col-sm-4 > p")
titles = soup.select(".chart-content.col-xs-12.col-sm-8 > p > cite")
artists = soup.select(".chart-content.col-xs-12.col-sm-8 > p > em")
    
board_position_text = [board_position.get_text() for board_position in board_positions]
title_text = [title.get_text() for title in titles]
artist_text = [artist.get_text() for artist in artists]
    
leader_board_songs_info = {
        "Ranking": board_position_text,
        "Title": title_text,
        "Artist": artist_text
    }
    
singer_songs_list = pd.DataFrame(leader_board_songs_info)
singer_songs_list.head(20)
# Out:
#    Ranking                                          Title  \
# 0        1                                    Lovin On Me
# 1        2                                  Lil Boo Thang
# 2        3  I Remember Everything (feat. Kacey Musgraves)
# 3        4                                    White Horse
# 4        5                   Save Me (with Lainey Wilson)
# 5        6                                    Lovin On Me
# 6        7                                   Need A Favor
# 7        8                                 90s Rap Mashup
# 8        9                                   Cruel Summer
# 9       10                                       Daylight
# 10      11                               Thinkin’ Bout Me
# 11      12                                        Houdini
# 12      13      Christmas / Sarajevo 12/24 (Instrumental)
# 13      14                                   Lose Control
# 14      15                All I Want for Christmas Is You
# 15      16                           Standing Next to You
# 16      17                                     Last Night
# 17      18                                       Fast Car
# 18      19                                   Now And Then
# 19      20                                         greedy
#
#                       Artist
# 0                Jack Harlow
# 1               Paul Russell
# 2                 Zach Bryan
# 3            Chris Stapleton
# 4                 Jelly Roll
# 5                Jack Harlow
# 6                 Jelly Roll
# 7            Austin Williams
# 8               Taylor Swift
# 9              David Kushner
# 10             Morgan Wallen
# 11                  Dua Lipa
# 12  Trans-Siberian Orchestra
# 13               Teddy Swims
# 14              Mariah Carey
# 15                 Jung Kook
# 16             Morgan Wallen
# 17                Luke Combs
# 18               The Beatles
# 19                Tate McRae

# %% [markdown]
# ## Lab | Web Scraping Multiple Pages
# ### Expand the project Part 1

# %%
url2 = "https://www.billboard.com/charts/hot-100/"

# %%
response2 = requests.get(url2)
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.content, "html.parser")

# %%
titles = []
artists = []

for i in range(1, 110): 
    title_selector = f"#post-1479786 > div.pmc-paywall > div > div > div > div.chart-results-list.\/\/.lrv-u-padding-t-150.lrv-u-padding-t-050\\@mobile-max > div:nth-child({i + 1}) > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.u-border-b-0\\@mobile-max.lrv-u-border-color-grey-light.lrv-u-padding-l-1\\@mobile-max > h3"
    artist_selector = f"#post-1479786 > div.pmc-paywall > div > div > div > div.chart-results-list.\/\/.lrv-u-padding-t-150.lrv-u-padding-t-050\\@mobile-max > div:nth-child({i + 1}) > ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.u-border-b-0\\@mobile-max.lrv-u-border-color-grey-light.lrv-u-padding-l-1\\@mobile-max > span"

    title_element = soup2.select_one(title_selector)
    artist_element = soup2.select_one(artist_selector)

    if title_element:
        title = title_element.get_text(strip=True)
        titles.append(title)

    if artist_element:
        artist = artist_element.get_text(strip=True)
        artists.append(artist)

song_list = {'Title': titles, 'Artist': artists}
df_song = pd.DataFrame(song_list, index=range(1, len(titles) + 1))
df_song
# Out:
#                                                  Title  \
# 1                                         Cruel Summer
# 2                                          Lovin On Me
# 3                                   Paint The Town Red
# 4                                               Snooze
# 5    Is It Over Now? (Taylor's Version) [From The V...
# ..                                                 ...
# 96                                   Mi Ex Tenia Razon
# 97                               Different 'Round Here
# 98                         But I Got A Beer In My Hand
# 99                                    Better Than Ever
# 100                                  Soak City (Do It)
#
#                                     Artist
# 1                             Taylor Swift
# 2                              Jack Harlow
# 3                                 Doja Cat
# 4                                      SZA
# 5                             Taylor Swift
# ..                                     ...
# 96                                 Karol G
# 97        Riley Green Featuring Luke Combs
# 98                              Luke Bryan
# 99   YoungBoy Never Broke Again & Rod Wave
# 100                               310babii
#
# [100 rows x 2 columns]

# %%
print('Please Enter Your Favourite Song\'s Title and Artist !!!')
title = input('Title:').strip()
artist = input('Artist:').strip()
# Out:
# Please Enter Your Favourite Song's Title and Artist !!!
# Title:Snooze
# Artist:SZA

# %%
is_hot = False
def is_it_hot_song():
    for t,a in zip(df_song.Title, df_song.Artist):
        if (title == t) & (a== artist):
            return True

is_hot = is_it_hot_song()

if is_hot==True:
    print('Enjoy Another Hot song of billboard')
    display(df_song.sample())
# Out:
# Enjoy Another Hot song of billboard
#            Title      Artist
# 31  Stick Season  Noah Kahan

# %% [markdown]
# ## Fetch Songs from Spotify
#
# #### Authentification

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
file = open("secrets.txt","r")
content = file.read()
secrets_dict={}
for line in content.split('\n'):
    if len(line) > 0:
#         print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['ClientID'],
                                                           client_secret=secrets_dict['ClientSecret']))

# %% [markdown]
# ### Playlists

# %%
play_list_id = "1hMzceeWw7QiI6vaBkcEJO"

playlist = sp.user_playlist_tracks("spotify", play_list_id)
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1hMzceeWw7QiI6vaBkcEJO/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-11-26T09:03:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7abqAQhqbQVO2WgB2twSQL'},
#        'href': 'https://api.spotify.com/v1/artists/7abqAQhqbQVO2WgB2twSQL',
#        'id': '7abqAQhqbQVO2WgB2twSQL',
#        'name': 'MassiveMusic',
#        'type': 'artist',
#        'uri': 'spotify:artist:7abqAQhqbQVO2WgB2twSQL'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1pg4cYRkcyzktgD4CcX9JM'},
#      'href': 'https://api.spotify.com/v1/albums/1pg4cYRkcyzktgD4CcX9JM',
#      'id': '1pg4cYRkcyzktgD4CcX9JM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a5dff29771ceef7b8961e527',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a5dff29771ceef7b8961e527',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a5dff29771ceef7b8961e527',
#        'width': 64}],
#      'name': 'This Magic Moment (Crisp.nl Version)',
#      'release_date': '2021-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1pg4cYRkcyzktgD4CcX9JM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7abqAQhqbQVO2WgB2twSQL'},
#       'href': 'https://api.spotify.com/v1/artists/7abqAQhqbQVO2WgB2twSQL',
#       'id': '7abqAQhqbQVO2WgB2twSQL',
#       'name': 'MassiveMusic',
#       'type': 'artist',
#       'uri': 'spotify:artist:7abqAQhqbQVO2WgB2twSQL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 188696,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZSR42108889'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6uDlwsguxFDgbakvPyhChp'},
#     'href': 'https://api.spotify.com/v1/tracks/6uDlwsguxFDgbakvPyhChp',
#     'id': '6uDlwsguxFDgbakvPyhChp',
#     'is_local': False,
#     'name': 'This Magic Moment - Crisp.nl Version',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6906012f7064a3ad4ae5d9b7378d5124d61fc0e0?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6uDlwsguxFDgbakvPyhChp'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63GCe948jqVvNvFB0DmuGB'},
#        'href': 'https://api.spotify.com/v1/artists/63GCe948jqVvNvFB0DmuGB',
#        'id': '63GCe948jqVvNvFB0DmuGB',
#        'name': 'Hoosky',
#        'type': 'artist',
#        'uri': 'spotify:artist:63GCe948jqVvNvFB0DmuGB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#        'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#        'id': '2EMmqQQmszsCXfVfMRibOQ',
#        'name': 'La Fine Equipe',
#        'type': 'artist',
#        'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7bPasMSBOBrih7xATDtmgk'},
#      'href': 'https://api.spotify.com/v1/albums/7bPasMSBOBrih7xATDtmgk',
#      'id': '7bPasMSBOBrih7xATDtmgk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362ec58f53178ec589f818d28',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262ec58f53178ec589f818d28',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162ec58f53178ec589f818d28',
#        'width': 64}],
#      'name': "Just a Lil' Beat, Vol. 1 (OOgo & Chomsk')",
#      'release_date': '2012-05-14',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:7bPasMSBOBrih7xATDtmgk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63GCe948jqVvNvFB0DmuGB'},
#       'href': 'https://api.spotify.com/v1/artists/63GCe948jqVvNvFB0DmuGB',
#       'id': '63GCe948jqVvNvFB0DmuGB',
#       'name': 'Hoosky',
#       'type': 'artist',
#       'uri': 'spotify:artist:63GCe948jqVvNvFB0DmuGB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#       'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#       'id': '2EMmqQQmszsCXfVfMRibOQ',
#       'name': 'La Fine Equipe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mM65AjhdrTa1eDExLKRsu'},
#       'href': 'https://api.spotify.com/v1/artists/1mM65AjhdrTa1eDExLKRsu',
#       'id': '1mM65AjhdrTa1eDExLKRsu',
#       'name': 'oOgo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mM65AjhdrTa1eDExLKRsu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CJDBEjJQYGcyC12FI1L0b'},
#       'href': 'https://api.spotify.com/v1/artists/0CJDBEjJQYGcyC12FI1L0b',
#       'id': '0CJDBEjJQYGcyC12FI1L0b',
#       'name': "Chomsk'",
#       'type': 'artist',
#       'uri': 'spotify:artist:0CJDBEjJQYGcyC12FI1L0b'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 51373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR0Z41200100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00LvjMnpznr4MZFSA8x9sA'},
#     'href': 'https://api.spotify.com/v1/tracks/00LvjMnpznr4MZFSA8x9sA',
#     'id': '00LvjMnpznr4MZFSA8x9sA',
#     'is_local': False,
#     'name': '00h00',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3d9a8ac204cfcba4a61ba9ecb629e0fb31d7090d?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:00LvjMnpznr4MZFSA8x9sA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#        'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#        'id': '22bE4uQ6baNwSHPVcDxLCe',
#        'name': 'The Rolling Stones',
#        'type': 'artist',
#        'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19MOC02Ei3l2SalGUGWozw'},
#      'href': 'https://api.spotify.com/v1/albums/19MOC02Ei3l2SalGUGWozw',
#      'id': '19MOC02Ei3l2SalGUGWozw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fae436900a11f5bfbc49b3fc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fae436900a11f5bfbc49b3fc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fae436900a11f5bfbc49b3fc',
#        'width': 64}],
#      'name': 'Aftermath (Remastered)',
#      'release_date': '1966-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:19MOC02Ei3l2SalGUGWozw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#       'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#       'id': '22bE4uQ6baNwSHPVcDxLCe',
#       'name': 'The Rolling Stones',
#       'type': 'artist',
#       'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 221533,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA176610050'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E8gEvhLia6w9lQv3hfxzM'},
#     'href': 'https://api.spotify.com/v1/tracks/3E8gEvhLia6w9lQv3hfxzM',
#     'id': '3E8gEvhLia6w9lQv3hfxzM',
#     'is_local': False,
#     'name': 'Under My Thumb',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3E8gEvhLia6w9lQv3hfxzM'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sX0Hd7MDMIw0Xm4nsoAPt'},
#      'href': 'https://api.spotify.com/v1/albums/6sX0Hd7MDMIw0Xm4nsoAPt',
#      'id': '6sX0Hd7MDMIw0Xm4nsoAPt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d263f58adcca6bfc301006d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d263f58adcca6bfc301006d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d263f58adcca6bfc301006d',
#        'width': 64}],
#      'name': 'March of the Gremlins',
#      'release_date': '2014-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6sX0Hd7MDMIw0Xm4nsoAPt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KiGbqbUvt60cttkqLfPEq'},
#       'href': 'https://api.spotify.com/v1/artists/5KiGbqbUvt60cttkqLfPEq',
#       'id': '5KiGbqbUvt60cttkqLfPEq',
#       'name': 'Jane B',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KiGbqbUvt60cttkqLfPEq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 216234,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEGT81400256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2jjPlj6KFzCffJ7KVQMwHX'},
#     'href': 'https://api.spotify.com/v1/tracks/2jjPlj6KFzCffJ7KVQMwHX',
#     'id': '2jjPlj6KFzCffJ7KVQMwHX',
#     'is_local': False,
#     'name': 'Conquer Me',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2jjPlj6KFzCffJ7KVQMwHX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-10-27T09:04:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vHBuUxrcpn1do5UaEJ7g6'},
#        'href': 'https://api.spotify.com/v1/artists/6vHBuUxrcpn1do5UaEJ7g6',
#        'id': '6vHBuUxrcpn1do5UaEJ7g6',
#        'name': 'Domo Genesis',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vHBuUxrcpn1do5UaEJ7g6'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/35pzihogLsPIl48ZBykD4l'},
#      'href': 'https://api.spotify.com/v1/albums/35pzihogLsPIl48ZBykD4l',
#      'id': '35pzihogLsPIl48ZBykD4l',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27380a60ff1516832f6c71b34a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0280a60ff1516832f6c71b34a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485180a60ff1516832f6c71b34a5',
#        'width': 64}],
#      'name': 'Dapper (feat. Anderson .Paak)',
#      'release_date': '2016-03-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:35pzihogLsPIl48ZBykD4l'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vHBuUxrcpn1do5UaEJ7g6'},
#       'href': 'https://api.spotify.com/v1/artists/6vHBuUxrcpn1do5UaEJ7g6',
#       'id': '6vHBuUxrcpn1do5UaEJ7g6',
#       'name': 'Domo Genesis',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vHBuUxrcpn1do5UaEJ7g6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jK9MiCrA42lLAdMGUZpwa'},
#       'href': 'https://api.spotify.com/v1/artists/3jK9MiCrA42lLAdMGUZpwa',
#       'id': '3jK9MiCrA42lLAdMGUZpwa',
#       'name': 'Anderson .Paak',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jK9MiCrA42lLAdMGUZpwa'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 193093,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQX91600320'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3seHx466iTcUmWE9dOVB3v'},
#     'href': 'https://api.spotify.com/v1/tracks/3seHx466iTcUmWE9dOVB3v',
#     'id': '3seHx466iTcUmWE9dOVB3v',
#     'is_local': False,
#     'name': 'Dapper (feat. Anderson .Paak)',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bc35e40cee1f733c8b067f6f5ebe8369ac45aee1?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3seHx466iTcUmWE9dOVB3v'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0asVlqTLu3TimnYVyY5Jxi'},
#        'href': 'https://api.spotify.com/v1/artists/0asVlqTLu3TimnYVyY5Jxi',
#        'id': '0asVlqTLu3TimnYVyY5Jxi',
#        'name': 'Tune-Yards',
#        'type': 'artist',
#        'uri': 'spotify:artist:0asVlqTLu3TimnYVyY5Jxi'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7i4Ou3Yn0KULwehLo9XupB'},
#      'href': 'https://api.spotify.com/v1/albums/7i4Ou3Yn0KULwehLo9XupB',
#      'id': '7i4Ou3Yn0KULwehLo9XupB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f26a898a8e5117cae2911ae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f26a898a8e5117cae2911ae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f26a898a8e5117cae2911ae',
#        'width': 64}],
#      'name': 'Water Fountain',
#      'release_date': '2014-03-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7i4Ou3Yn0KULwehLo9XupB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0asVlqTLu3TimnYVyY5Jxi'},
#       'href': 'https://api.spotify.com/v1/artists/0asVlqTLu3TimnYVyY5Jxi',
#       'id': '0asVlqTLu3TimnYVyY5Jxi',
#       'name': 'Tune-Yards',
#       'type': 'artist',
#       'uri': 'spotify:artist:0asVlqTLu3TimnYVyY5Jxi'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 183453,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBAFL1400016'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3pndgH9sLDTCWtCwr8LWt9'},
#     'href': 'https://api.spotify.com/v1/tracks/3pndgH9sLDTCWtCwr8LWt9',
#     'id': '3pndgH9sLDTCWtCwr8LWt9',
#     'is_local': False,
#     'name': 'Water Fountain',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3pndgH9sLDTCWtCwr8LWt9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#        'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#        'id': '2QsynagSdAqZj3U9HgDzjD',
#        'name': 'Bob Marley & The Wailers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Rgvd4zLszlY2ePfvu1tr0'},
#      'href': 'https://api.spotify.com/v1/albums/4Rgvd4zLszlY2ePfvu1tr0',
#      'id': '4Rgvd4zLszlY2ePfvu1tr0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27326204093d8bdaba97ab0c8e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0226204093d8bdaba97ab0c8e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485126204093d8bdaba97ab0c8e2',
#        'width': 64}],
#      'name': 'African Herbsman (Deluxe Edition)',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:4Rgvd4zLszlY2ePfvu1tr0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#       'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#       'id': '2QsynagSdAqZj3U9HgDzjD',
#       'name': 'Bob Marley & The Wailers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 134573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJE7000696'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3PPigifoeEofIISQYbayMK'},
#     'href': 'https://api.spotify.com/v1/tracks/3PPigifoeEofIISQYbayMK',
#     'id': '3PPigifoeEofIISQYbayMK',
#     'is_local': False,
#     'name': 'Sun Is Shining',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3PPigifoeEofIISQYbayMK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dBVyJ7JuOMt4GE9607Qin'},
#        'href': 'https://api.spotify.com/v1/artists/3dBVyJ7JuOMt4GE9607Qin',
#        'id': '3dBVyJ7JuOMt4GE9607Qin',
#        'name': 'T. Rex',
#        'type': 'artist',
#        'uri': 'spotify:artist:3dBVyJ7JuOMt4GE9607Qin'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0pISVqir1RELSEnbwu65OF'},
#      'href': 'https://api.spotify.com/v1/albums/0pISVqir1RELSEnbwu65OF',
#      'id': '0pISVqir1RELSEnbwu65OF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a400a5d8c0d6921dc75ad867',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a400a5d8c0d6921dc75ad867',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a400a5d8c0d6921dc75ad867',
#        'width': 64}],
#      'name': 'Classic T Rex',
#      'release_date': '2003-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0pISVqir1RELSEnbwu65OF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dBVyJ7JuOMt4GE9607Qin'},
#       'href': 'https://api.spotify.com/v1/artists/3dBVyJ7JuOMt4GE9607Qin',
#       'id': '3dBVyJ7JuOMt4GE9607Qin',
#       'name': 'T. Rex',
#       'type': 'artist',
#       'uri': 'spotify:artist:3dBVyJ7JuOMt4GE9607Qin'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 132800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCHM0000080'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3olQaoZDc2O1mFDod0evZI'},
#     'href': 'https://api.spotify.com/v1/tracks/3olQaoZDc2O1mFDod0evZI',
#     'id': '3olQaoZDc2O1mFDod0evZI',
#     'is_local': False,
#     'name': 'Ride A White Swan',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3olQaoZDc2O1mFDod0evZI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3JHCqXHLS46aDpgVmypkib'},
#      'href': 'https://api.spotify.com/v1/albums/3JHCqXHLS46aDpgVmypkib',
#      'id': '3JHCqXHLS46aDpgVmypkib',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732517a12a5cae89e08331bf6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022517a12a5cae89e08331bf6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512517a12a5cae89e08331bf6f',
#        'width': 64}],
#      'name': 'Stax Chartbusters, Vol. 6',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:3JHCqXHLS46aDpgVmypkib'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8UTum7bU7ue6m0r14H97'},
#       'href': 'https://api.spotify.com/v1/artists/2W8UTum7bU7ue6m0r14H97',
#       'id': '2W8UTum7bU7ue6m0r14H97',
#       'name': 'The Dramatics',
#       'type': 'artist',
#       'uri': 'spotify:artist:2W8UTum7bU7ue6m0r14H97'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 212840,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFI80700432'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6J7uQ9vLtBqNikEhlKUOnu'},
#     'href': 'https://api.spotify.com/v1/tracks/6J7uQ9vLtBqNikEhlKUOnu',
#     'id': '6J7uQ9vLtBqNikEhlKUOnu',
#     'is_local': False,
#     'name': 'Whatcha See Is Whatcha Get',
#     'popularity': 25,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6J7uQ9vLtBqNikEhlKUOnu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#        'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#        'id': '7IfculRW2WXyzNQ8djX8WX',
#        'name': 'Erykah Badu',
#        'type': 'artist',
#        'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'}],
#      'available_markets': ['GB', 'IE'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4z7ma1ujO4FDL1l2YBGw7b'},
#      'href': 'https://api.spotify.com/v1/albums/4z7ma1ujO4FDL1l2YBGw7b',
#      'id': '4z7ma1ujO4FDL1l2YBGw7b',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350442c2d5d3573d7cac43567',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250442c2d5d3573d7cac43567',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150442c2d5d3573d7cac43567',
#        'width': 64}],
#      'name': "Mama's Gun",
#      'release_date': '2000-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4z7ma1ujO4FDL1l2YBGw7b'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#       'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#       'id': '7IfculRW2WXyzNQ8djX8WX',
#       'name': 'Erykah Badu',
#       'type': 'artist',
#       'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CIwCGmQMqHqiblnZlFia1'},
#       'href': 'https://api.spotify.com/v1/artists/0CIwCGmQMqHqiblnZlFia1',
#       'id': '0CIwCGmQMqHqiblnZlFia1',
#       'name': 'Stephen Marley',
#       'type': 'artist',
#       'uri': 'spotify:artist:0CIwCGmQMqHqiblnZlFia1'}],
#     'available_markets': ['GB', 'IE'],
#     'disc_number': 1,
#     'duration_ms': 322533,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO10001023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6uI95ERPZV6tivkNWsOKet'},
#     'href': 'https://api.spotify.com/v1/tracks/6uI95ERPZV6tivkNWsOKet',
#     'id': '6uI95ERPZV6tivkNWsOKet',
#     'is_local': False,
#     'name': 'In Love With You',
#     'popularity': 38,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6uI95ERPZV6tivkNWsOKet'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tpUmLEVLCGFr93o8hFFIB'},
#        'href': 'https://api.spotify.com/v1/artists/4tpUmLEVLCGFr93o8hFFIB',
#        'id': '4tpUmLEVLCGFr93o8hFFIB',
#        'name': 'Blondie',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tpUmLEVLCGFr93o8hFFIB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7mEjsBlRmfP63cH1gdPT6A'},
#      'href': 'https://api.spotify.com/v1/albums/7mEjsBlRmfP63cH1gdPT6A',
#      'id': '7mEjsBlRmfP63cH1gdPT6A',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738cf86a9be38868f1d73cdb58',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028cf86a9be38868f1d73cdb58',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518cf86a9be38868f1d73cdb58',
#        'width': 64}],
#      'name': 'Best Of Blondie',
#      'release_date': '1981-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7mEjsBlRmfP63cH1gdPT6A'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tpUmLEVLCGFr93o8hFFIB'},
#       'href': 'https://api.spotify.com/v1/artists/4tpUmLEVLCGFr93o8hFFIB',
#       'id': '4tpUmLEVLCGFr93o8hFFIB',
#       'name': 'Blondie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tpUmLEVLCGFr93o8hFFIB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dXUks6yUrIy5IYKFn45iq'},
#       'href': 'https://api.spotify.com/v1/artists/7dXUks6yUrIy5IYKFn45iq',
#       'id': '7dXUks6yUrIy5IYKFn45iq',
#       'name': 'Mike Chapman',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dXUks6yUrIy5IYKFn45iq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 185066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA28100065'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/23yv078f5kc08Kj6DMpO0t'},
#     'href': 'https://api.spotify.com/v1/tracks/23yv078f5kc08Kj6DMpO0t',
#     'id': '23yv078f5kc08Kj6DMpO0t',
#     'is_local': False,
#     'name': 'Sunday Girl',
#     'popularity': 40,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:23yv078f5kc08Kj6DMpO0t'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#        'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#        'id': '2Jv5eshHtLycR6R8KQCdc4',
#        'name': 'Grizzly Bear',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#      'available_markets': [],
# ...
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39wovx5sCg0UkoTF7nBG2X'},
#        'href': 'https://api.spotify.com/v1/artists/39wovx5sCg0UkoTF7nBG2X',
#        'id': '39wovx5sCg0UkoTF7nBG2X',
#        'name': 'Wampire',
#        'type': 'artist',
#        'uri': 'spotify:artist:39wovx5sCg0UkoTF7nBG2X'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mhzdJ2ILI1LgQTDmGGygi'},
#      'href': 'https://api.spotify.com/v1/albums/4mhzdJ2ILI1LgQTDmGGygi',
#      'id': '4mhzdJ2ILI1LgQTDmGGygi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a46ccd8abb326df79e8f1345',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a46ccd8abb326df79e8f1345',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a46ccd8abb326df79e8f1345',
#        'width': 64}],
#      'name': 'The Hearse',
#      'release_date': '2013-03-04',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4mhzdJ2ILI1LgQTDmGGygi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39wovx5sCg0UkoTF7nBG2X'},
#       'href': 'https://api.spotify.com/v1/artists/39wovx5sCg0UkoTF7nBG2X',
#       'id': '39wovx5sCg0UkoTF7nBG2X',
#       'name': 'Wampire',
#       'type': 'artist',
#       'uri': 'spotify:artist:39wovx5sCg0UkoTF7nBG2X'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 280106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US3R41325701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1JGXx7CG3CxUYmuaNLyuQ3'},
#     'href': 'https://api.spotify.com/v1/tracks/1JGXx7CG3CxUYmuaNLyuQ3',
#     'id': '1JGXx7CG3CxUYmuaNLyuQ3',
#     'is_local': False,
#     'name': 'The Hearse',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1JGXx7CG3CxUYmuaNLyuQ3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QgSmABpItIdj908ek80n5'},
#        'href': 'https://api.spotify.com/v1/artists/3QgSmABpItIdj908ek80n5',
#        'id': '3QgSmABpItIdj908ek80n5',
#        'name': 'Morphine',
#        'type': 'artist',
#        'uri': 'spotify:artist:3QgSmABpItIdj908ek80n5'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FocpOyE7RnaNsiaEhSbp6'},
#      'href': 'https://api.spotify.com/v1/albums/0FocpOyE7RnaNsiaEhSbp6',
#      'id': '0FocpOyE7RnaNsiaEhSbp6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b0f39b11297dc844ed04c36a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b0f39b11297dc844ed04c36a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b0f39b11297dc844ed04c36a',
#        'width': 64}],
#      'name': 'Cure for Pain',
#      'release_date': '1993-09-14',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0FocpOyE7RnaNsiaEhSbp6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QgSmABpItIdj908ek80n5'},
#       'href': 'https://api.spotify.com/v1/artists/3QgSmABpItIdj908ek80n5',
#       'id': '3QgSmABpItIdj908ek80n5',
#       'name': 'Morphine',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QgSmABpItIdj908ek80n5'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 199666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRY10262002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SSBJhvMsujY94GK5JAtKs'},
#     'href': 'https://api.spotify.com/v1/tracks/2SSBJhvMsujY94GK5JAtKs',
#     'id': '2SSBJhvMsujY94GK5JAtKs',
#     'is_local': False,
#     'name': 'Buena',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f2ab48e8b32af961c27431173358453b55c30f1b?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2SSBJhvMsujY94GK5JAtKs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2014-06-20T16:10:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#     'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#     'id': 'massivemusic.com',
#     'type': 'user',
#     'uri': 'spotify:user:massivemusic.com'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WoeMzXhDQyoFCKdji4FlL'},
#        'href': 'https://api.spotify.com/v1/artists/4WoeMzXhDQyoFCKdji4FlL',
#        'id': '4WoeMzXhDQyoFCKdji4FlL',
#        'name': 'Amp Live',
#        'type': 'artist',
#        'uri': 'spotify:artist:4WoeMzXhDQyoFCKdji4FlL'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27pXB0rSC5c2xRCQgaibOy'},
#      'href': 'https://api.spotify.com/v1/albums/27pXB0rSC5c2xRCQgaibOy',
#      'id': '27pXB0rSC5c2xRCQgaibOy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b43321704101cafb79d2492',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b43321704101cafb79d2492',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b43321704101cafb79d2492',
#        'width': 64}],
#      'name': 'Kaleidoscope Theory EP',
#      'release_date': '2012',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:27pXB0rSC5c2xRCQgaibOy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WoeMzXhDQyoFCKdji4FlL'},
#       'href': 'https://api.spotify.com/v1/artists/4WoeMzXhDQyoFCKdji4FlL',
#       'id': '4WoeMzXhDQyoFCKdji4FlL',
#       'name': 'Amp Live',
#       'type': 'artist',
#       'uri': 'spotify:artist:4WoeMzXhDQyoFCKdji4FlL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 286756,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPG21200181'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7azrHbFNpxZNncn9BXpaW1'},
#     'href': 'https://api.spotify.com/v1/tracks/7azrHbFNpxZNncn9BXpaW1',
#     'id': '7azrHbFNpxZNncn9BXpaW1',
#     'is_local': False,
#     'name': 'D.H.E.A.',
#     'popularity': 4,
#     'preview_url': 'https://p.scdn.co/mp3-preview/da062303fe0254fb0ea71d8429446443f62d0bff?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7azrHbFNpxZNncn9BXpaW1'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/1hMzceeWw7QiI6vaBkcEJO/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 10000}

# %%
playlist["total"]
# Out:
# 10000

# %%
playlist['items']
# Out:
# [{'added_at': '2021-11-26T09:03:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7abqAQhqbQVO2WgB2twSQL'},
#       'href': 'https://api.spotify.com/v1/artists/7abqAQhqbQVO2WgB2twSQL',
#       'id': '7abqAQhqbQVO2WgB2twSQL',
#       'name': 'MassiveMusic',
#       'type': 'artist',
#       'uri': 'spotify:artist:7abqAQhqbQVO2WgB2twSQL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1pg4cYRkcyzktgD4CcX9JM'},
#     'href': 'https://api.spotify.com/v1/albums/1pg4cYRkcyzktgD4CcX9JM',
#     'id': '1pg4cYRkcyzktgD4CcX9JM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a5dff29771ceef7b8961e527',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a5dff29771ceef7b8961e527',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a5dff29771ceef7b8961e527',
#       'width': 64}],
#     'name': 'This Magic Moment (Crisp.nl Version)',
#     'release_date': '2021-11-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1pg4cYRkcyzktgD4CcX9JM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7abqAQhqbQVO2WgB2twSQL'},
#      'href': 'https://api.spotify.com/v1/artists/7abqAQhqbQVO2WgB2twSQL',
#      'id': '7abqAQhqbQVO2WgB2twSQL',
#      'name': 'MassiveMusic',
#      'type': 'artist',
#      'uri': 'spotify:artist:7abqAQhqbQVO2WgB2twSQL'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 188696,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZSR42108889'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6uDlwsguxFDgbakvPyhChp'},
#    'href': 'https://api.spotify.com/v1/tracks/6uDlwsguxFDgbakvPyhChp',
#    'id': '6uDlwsguxFDgbakvPyhChp',
#    'is_local': False,
#    'name': 'This Magic Moment - Crisp.nl Version',
#    'popularity': 19,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6906012f7064a3ad4ae5d9b7378d5124d61fc0e0?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6uDlwsguxFDgbakvPyhChp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63GCe948jqVvNvFB0DmuGB'},
#       'href': 'https://api.spotify.com/v1/artists/63GCe948jqVvNvFB0DmuGB',
#       'id': '63GCe948jqVvNvFB0DmuGB',
#       'name': 'Hoosky',
#       'type': 'artist',
#       'uri': 'spotify:artist:63GCe948jqVvNvFB0DmuGB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#       'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#       'id': '2EMmqQQmszsCXfVfMRibOQ',
#       'name': 'La Fine Equipe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7bPasMSBOBrih7xATDtmgk'},
#     'href': 'https://api.spotify.com/v1/albums/7bPasMSBOBrih7xATDtmgk',
#     'id': '7bPasMSBOBrih7xATDtmgk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27362ec58f53178ec589f818d28',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0262ec58f53178ec589f818d28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485162ec58f53178ec589f818d28',
#       'width': 64}],
#     'name': "Just a Lil' Beat, Vol. 1 (OOgo & Chomsk')",
#     'release_date': '2012-05-14',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:7bPasMSBOBrih7xATDtmgk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63GCe948jqVvNvFB0DmuGB'},
#      'href': 'https://api.spotify.com/v1/artists/63GCe948jqVvNvFB0DmuGB',
#      'id': '63GCe948jqVvNvFB0DmuGB',
#      'name': 'Hoosky',
#      'type': 'artist',
#      'uri': 'spotify:artist:63GCe948jqVvNvFB0DmuGB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#      'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#      'id': '2EMmqQQmszsCXfVfMRibOQ',
#      'name': 'La Fine Equipe',
#      'type': 'artist',
#      'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mM65AjhdrTa1eDExLKRsu'},
#      'href': 'https://api.spotify.com/v1/artists/1mM65AjhdrTa1eDExLKRsu',
#      'id': '1mM65AjhdrTa1eDExLKRsu',
#      'name': 'oOgo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mM65AjhdrTa1eDExLKRsu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CJDBEjJQYGcyC12FI1L0b'},
#      'href': 'https://api.spotify.com/v1/artists/0CJDBEjJQYGcyC12FI1L0b',
#      'id': '0CJDBEjJQYGcyC12FI1L0b',
#      'name': "Chomsk'",
#      'type': 'artist',
#      'uri': 'spotify:artist:0CJDBEjJQYGcyC12FI1L0b'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 51373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR0Z41200100'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/00LvjMnpznr4MZFSA8x9sA'},
#    'href': 'https://api.spotify.com/v1/tracks/00LvjMnpznr4MZFSA8x9sA',
#    'id': '00LvjMnpznr4MZFSA8x9sA',
#    'is_local': False,
#    'name': '00h00',
#    'popularity': 7,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3d9a8ac204cfcba4a61ba9ecb629e0fb31d7090d?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:00LvjMnpznr4MZFSA8x9sA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#       'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#       'id': '22bE4uQ6baNwSHPVcDxLCe',
#       'name': 'The Rolling Stones',
#       'type': 'artist',
#       'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19MOC02Ei3l2SalGUGWozw'},
#     'href': 'https://api.spotify.com/v1/albums/19MOC02Ei3l2SalGUGWozw',
#     'id': '19MOC02Ei3l2SalGUGWozw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fae436900a11f5bfbc49b3fc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fae436900a11f5bfbc49b3fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fae436900a11f5bfbc49b3fc',
#       'width': 64}],
#     'name': 'Aftermath (Remastered)',
#     'release_date': '1966-04-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:19MOC02Ei3l2SalGUGWozw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#      'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#      'id': '22bE4uQ6baNwSHPVcDxLCe',
#      'name': 'The Rolling Stones',
#      'type': 'artist',
#      'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 221533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA176610050'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3E8gEvhLia6w9lQv3hfxzM'},
#    'href': 'https://api.spotify.com/v1/tracks/3E8gEvhLia6w9lQv3hfxzM',
#    'id': '3E8gEvhLia6w9lQv3hfxzM',
#    'is_local': False,
#    'name': 'Under My Thumb',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3E8gEvhLia6w9lQv3hfxzM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6sX0Hd7MDMIw0Xm4nsoAPt'},
#     'href': 'https://api.spotify.com/v1/albums/6sX0Hd7MDMIw0Xm4nsoAPt',
#     'id': '6sX0Hd7MDMIw0Xm4nsoAPt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735d263f58adcca6bfc301006d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025d263f58adcca6bfc301006d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515d263f58adcca6bfc301006d',
#       'width': 64}],
#     'name': 'March of the Gremlins',
#     'release_date': '2014-01-20',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6sX0Hd7MDMIw0Xm4nsoAPt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KiGbqbUvt60cttkqLfPEq'},
#      'href': 'https://api.spotify.com/v1/artists/5KiGbqbUvt60cttkqLfPEq',
#      'id': '5KiGbqbUvt60cttkqLfPEq',
#      'name': 'Jane B',
#      'type': 'artist',
#      'uri': 'spotify:artist:5KiGbqbUvt60cttkqLfPEq'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 216234,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEGT81400256'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2jjPlj6KFzCffJ7KVQMwHX'},
#    'href': 'https://api.spotify.com/v1/tracks/2jjPlj6KFzCffJ7KVQMwHX',
#    'id': '2jjPlj6KFzCffJ7KVQMwHX',
#    'is_local': False,
#    'name': 'Conquer Me',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2jjPlj6KFzCffJ7KVQMwHX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-10-27T09:04:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vHBuUxrcpn1do5UaEJ7g6'},
#       'href': 'https://api.spotify.com/v1/artists/6vHBuUxrcpn1do5UaEJ7g6',
#       'id': '6vHBuUxrcpn1do5UaEJ7g6',
#       'name': 'Domo Genesis',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vHBuUxrcpn1do5UaEJ7g6'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/35pzihogLsPIl48ZBykD4l'},
#     'href': 'https://api.spotify.com/v1/albums/35pzihogLsPIl48ZBykD4l',
#     'id': '35pzihogLsPIl48ZBykD4l',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27380a60ff1516832f6c71b34a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0280a60ff1516832f6c71b34a5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485180a60ff1516832f6c71b34a5',
#       'width': 64}],
#     'name': 'Dapper (feat. Anderson .Paak)',
#     'release_date': '2016-03-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:35pzihogLsPIl48ZBykD4l'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vHBuUxrcpn1do5UaEJ7g6'},
#      'href': 'https://api.spotify.com/v1/artists/6vHBuUxrcpn1do5UaEJ7g6',
#      'id': '6vHBuUxrcpn1do5UaEJ7g6',
#      'name': 'Domo Genesis',
#      'type': 'artist',
#      'uri': 'spotify:artist:6vHBuUxrcpn1do5UaEJ7g6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jK9MiCrA42lLAdMGUZpwa'},
#      'href': 'https://api.spotify.com/v1/artists/3jK9MiCrA42lLAdMGUZpwa',
#      'id': '3jK9MiCrA42lLAdMGUZpwa',
#      'name': 'Anderson .Paak',
#      'type': 'artist',
#      'uri': 'spotify:artist:3jK9MiCrA42lLAdMGUZpwa'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 193093,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX91600320'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3seHx466iTcUmWE9dOVB3v'},
#    'href': 'https://api.spotify.com/v1/tracks/3seHx466iTcUmWE9dOVB3v',
#    'id': '3seHx466iTcUmWE9dOVB3v',
#    'is_local': False,
#    'name': 'Dapper (feat. Anderson .Paak)',
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bc35e40cee1f733c8b067f6f5ebe8369ac45aee1?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3seHx466iTcUmWE9dOVB3v'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0asVlqTLu3TimnYVyY5Jxi'},
#       'href': 'https://api.spotify.com/v1/artists/0asVlqTLu3TimnYVyY5Jxi',
#       'id': '0asVlqTLu3TimnYVyY5Jxi',
#       'name': 'Tune-Yards',
#       'type': 'artist',
#       'uri': 'spotify:artist:0asVlqTLu3TimnYVyY5Jxi'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7i4Ou3Yn0KULwehLo9XupB'},
#     'href': 'https://api.spotify.com/v1/albums/7i4Ou3Yn0KULwehLo9XupB',
#     'id': '7i4Ou3Yn0KULwehLo9XupB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736f26a898a8e5117cae2911ae',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026f26a898a8e5117cae2911ae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516f26a898a8e5117cae2911ae',
#       'width': 64}],
#     'name': 'Water Fountain',
#     'release_date': '2014-03-18',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7i4Ou3Yn0KULwehLo9XupB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0asVlqTLu3TimnYVyY5Jxi'},
#      'href': 'https://api.spotify.com/v1/artists/0asVlqTLu3TimnYVyY5Jxi',
#      'id': '0asVlqTLu3TimnYVyY5Jxi',
#      'name': 'Tune-Yards',
#      'type': 'artist',
#      'uri': 'spotify:artist:0asVlqTLu3TimnYVyY5Jxi'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 183453,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAFL1400016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3pndgH9sLDTCWtCwr8LWt9'},
#    'href': 'https://api.spotify.com/v1/tracks/3pndgH9sLDTCWtCwr8LWt9',
#    'id': '3pndgH9sLDTCWtCwr8LWt9',
#    'is_local': False,
#    'name': 'Water Fountain',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3pndgH9sLDTCWtCwr8LWt9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#       'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#       'id': '2QsynagSdAqZj3U9HgDzjD',
#       'name': 'Bob Marley & The Wailers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Rgvd4zLszlY2ePfvu1tr0'},
#     'href': 'https://api.spotify.com/v1/albums/4Rgvd4zLszlY2ePfvu1tr0',
#     'id': '4Rgvd4zLszlY2ePfvu1tr0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27326204093d8bdaba97ab0c8e2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0226204093d8bdaba97ab0c8e2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485126204093d8bdaba97ab0c8e2',
#       'width': 64}],
#     'name': 'African Herbsman (Deluxe Edition)',
#     'release_date': '2003',
#     'release_date_precision': 'year',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4Rgvd4zLszlY2ePfvu1tr0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#      'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#      'id': '2QsynagSdAqZj3U9HgDzjD',
#      'name': 'Bob Marley & The Wailers',
#      'type': 'artist',
#      'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 134573,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE7000696'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3PPigifoeEofIISQYbayMK'},
#    'href': 'https://api.spotify.com/v1/tracks/3PPigifoeEofIISQYbayMK',
#    'id': '3PPigifoeEofIISQYbayMK',
#    'is_local': False,
#    'name': 'Sun Is Shining',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:3PPigifoeEofIISQYbayMK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dBVyJ7JuOMt4GE9607Qin'},
#       'href': 'https://api.spotify.com/v1/artists/3dBVyJ7JuOMt4GE9607Qin',
#       'id': '3dBVyJ7JuOMt4GE9607Qin',
#       'name': 'T. Rex',
#       'type': 'artist',
#       'uri': 'spotify:artist:3dBVyJ7JuOMt4GE9607Qin'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0pISVqir1RELSEnbwu65OF'},
#     'href': 'https://api.spotify.com/v1/albums/0pISVqir1RELSEnbwu65OF',
#     'id': '0pISVqir1RELSEnbwu65OF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a400a5d8c0d6921dc75ad867',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a400a5d8c0d6921dc75ad867',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a400a5d8c0d6921dc75ad867',
#       'width': 64}],
#     'name': 'Classic T Rex',
#     'release_date': '2003-10-13',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:0pISVqir1RELSEnbwu65OF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3dBVyJ7JuOMt4GE9607Qin'},
#      'href': 'https://api.spotify.com/v1/artists/3dBVyJ7JuOMt4GE9607Qin',
#      'id': '3dBVyJ7JuOMt4GE9607Qin',
#      'name': 'T. Rex',
#      'type': 'artist',
#      'uri': 'spotify:artist:3dBVyJ7JuOMt4GE9607Qin'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 132800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCHM0000080'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3olQaoZDc2O1mFDod0evZI'},
#    'href': 'https://api.spotify.com/v1/tracks/3olQaoZDc2O1mFDod0evZI',
#    'id': '3olQaoZDc2O1mFDod0evZI',
#    'is_local': False,
#    'name': 'Ride A White Swan',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3olQaoZDc2O1mFDod0evZI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3JHCqXHLS46aDpgVmypkib'},
#     'href': 'https://api.spotify.com/v1/albums/3JHCqXHLS46aDpgVmypkib',
#     'id': '3JHCqXHLS46aDpgVmypkib',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732517a12a5cae89e08331bf6f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022517a12a5cae89e08331bf6f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512517a12a5cae89e08331bf6f',
#       'width': 64}],
#     'name': 'Stax Chartbusters, Vol. 6',
#     'release_date': '2008-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:3JHCqXHLS46aDpgVmypkib'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2W8UTum7bU7ue6m0r14H97'},
#      'href': 'https://api.spotify.com/v1/artists/2W8UTum7bU7ue6m0r14H97',
#      'id': '2W8UTum7bU7ue6m0r14H97',
#      'name': 'The Dramatics',
#      'type': 'artist',
#      'uri': 'spotify:artist:2W8UTum7bU7ue6m0r14H97'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'disc_number': 1,
#    'duration_ms': 212840,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USFI80700432'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6J7uQ9vLtBqNikEhlKUOnu'},
#    'href': 'https://api.spotify.com/v1/tracks/6J7uQ9vLtBqNikEhlKUOnu',
#    'id': '6J7uQ9vLtBqNikEhlKUOnu',
#    'is_local': False,
#    'name': 'Whatcha See Is Whatcha Get',
#    'popularity': 25,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6J7uQ9vLtBqNikEhlKUOnu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#       'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#       'id': '7IfculRW2WXyzNQ8djX8WX',
#       'name': 'Erykah Badu',
#       'type': 'artist',
#       'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'}],
#     'available_markets': ['GB', 'IE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4z7ma1ujO4FDL1l2YBGw7b'},
#     'href': 'https://api.spotify.com/v1/albums/4z7ma1ujO4FDL1l2YBGw7b',
#     'id': '4z7ma1ujO4FDL1l2YBGw7b',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27350442c2d5d3573d7cac43567',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0250442c2d5d3573d7cac43567',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485150442c2d5d3573d7cac43567',
#       'width': 64}],
#     'name': "Mama's Gun",
#     'release_date': '2000-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:4z7ma1ujO4FDL1l2YBGw7b'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#      'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#      'id': '7IfculRW2WXyzNQ8djX8WX',
#      'name': 'Erykah Badu',
#      'type': 'artist',
#      'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CIwCGmQMqHqiblnZlFia1'},
#      'href': 'https://api.spotify.com/v1/artists/0CIwCGmQMqHqiblnZlFia1',
#      'id': '0CIwCGmQMqHqiblnZlFia1',
#      'name': 'Stephen Marley',
#      'type': 'artist',
#      'uri': 'spotify:artist:0CIwCGmQMqHqiblnZlFia1'}],
#    'available_markets': ['GB', 'IE'],
#    'disc_number': 1,
#    'duration_ms': 322533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO10001023'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6uI95ERPZV6tivkNWsOKet'},
#    'href': 'https://api.spotify.com/v1/tracks/6uI95ERPZV6tivkNWsOKet',
#    'id': '6uI95ERPZV6tivkNWsOKet',
#    'is_local': False,
#    'name': 'In Love With You',
#    'popularity': 38,
#    'preview_url': None,
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:6uI95ERPZV6tivkNWsOKet'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tpUmLEVLCGFr93o8hFFIB'},
#       'href': 'https://api.spotify.com/v1/artists/4tpUmLEVLCGFr93o8hFFIB',
#       'id': '4tpUmLEVLCGFr93o8hFFIB',
#       'name': 'Blondie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tpUmLEVLCGFr93o8hFFIB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7mEjsBlRmfP63cH1gdPT6A'},
#     'href': 'https://api.spotify.com/v1/albums/7mEjsBlRmfP63cH1gdPT6A',
#     'id': '7mEjsBlRmfP63cH1gdPT6A',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738cf86a9be38868f1d73cdb58',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028cf86a9be38868f1d73cdb58',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518cf86a9be38868f1d73cdb58',
#       'width': 64}],
#     'name': 'Best Of Blondie',
#     'release_date': '1981-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:7mEjsBlRmfP63cH1gdPT6A'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tpUmLEVLCGFr93o8hFFIB'},
#      'href': 'https://api.spotify.com/v1/artists/4tpUmLEVLCGFr93o8hFFIB',
#      'id': '4tpUmLEVLCGFr93o8hFFIB',
#      'name': 'Blondie',
#      'type': 'artist',
#      'uri': 'spotify:artist:4tpUmLEVLCGFr93o8hFFIB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dXUks6yUrIy5IYKFn45iq'},
#      'href': 'https://api.spotify.com/v1/artists/7dXUks6yUrIy5IYKFn45iq',
#      'id': '7dXUks6yUrIy5IYKFn45iq',
#      'name': 'Mike Chapman',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dXUks6yUrIy5IYKFn45iq'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 185066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA28100065'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/23yv078f5kc08Kj6DMpO0t'},
#    'href': 'https://api.spotify.com/v1/tracks/23yv078f5kc08Kj6DMpO0t',
#    'id': '23yv078f5kc08Kj6DMpO0t',
#    'is_local': False,
#    'name': 'Sunday Girl',
#    'popularity': 40,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:23yv078f5kc08Kj6DMpO0t'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#       'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#       'id': '2Jv5eshHtLycR6R8KQCdc4',
#       'name': 'Grizzly Bear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FIFqclBriPCb0SjWDaHIk'},
#     'href': 'https://api.spotify.com/v1/albums/6FIFqclBriPCb0SjWDaHIk',
#     'id': '6FIFqclBriPCb0SjWDaHIk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f5819f138439b3ac881a2a6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f5819f138439b3ac881a2a6b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f5819f138439b3ac881a2a6b',
#       'width': 64}],
#     'name': 'Veckatimest',
#     'release_date': '2009-05-24',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6FIFqclBriPCb0SjWDaHIk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#      'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#      'id': '2Jv5eshHtLycR6R8KQCdc4',
#      'name': 'Grizzly Bear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 243160,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBPW0900065'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0iTpQYzJnYgh7kIxyq8A2O'},
#    'href': 'https://api.spotify.com/v1/tracks/0iTpQYzJnYgh7kIxyq8A2O',
#    'id': '0iTpQYzJnYgh7kIxyq8A2O',
#    'is_local': False,
#    'name': 'Two Weeks',
#    'popularity': 2,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0iTpQYzJnYgh7kIxyq8A2O'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hv9jJF3adDNsBSIQDqcjp'},
#       'href': 'https://api.spotify.com/v1/artists/3hv9jJF3adDNsBSIQDqcjp',
#       'id': '3hv9jJF3adDNsBSIQDqcjp',
#       'name': 'Mark Ronson',
#       'type': 'artist',
# ...
#      'href': 'https://api.spotify.com/v1/artists/1TsG4AumsMt1Tcq2nHpov9',
#      'id': '1TsG4AumsMt1Tcq2nHpov9',
#      'name': 'Lee "Scratch" Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:1TsG4AumsMt1Tcq2nHpov9'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 270851,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEJ1300153'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2XlAjPUcsjkmYJgQbgvP5H'},
#    'href': 'https://api.spotify.com/v1/tracks/2XlAjPUcsjkmYJgQbgvP5H',
#    'id': '2XlAjPUcsjkmYJgQbgvP5H',
#    'is_local': False,
#    'name': 'Fussball',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2XlAjPUcsjkmYJgQbgvP5H'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39wovx5sCg0UkoTF7nBG2X'},
#       'href': 'https://api.spotify.com/v1/artists/39wovx5sCg0UkoTF7nBG2X',
#       'id': '39wovx5sCg0UkoTF7nBG2X',
#       'name': 'Wampire',
#       'type': 'artist',
#       'uri': 'spotify:artist:39wovx5sCg0UkoTF7nBG2X'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4mhzdJ2ILI1LgQTDmGGygi'},
#     'href': 'https://api.spotify.com/v1/albums/4mhzdJ2ILI1LgQTDmGGygi',
#     'id': '4mhzdJ2ILI1LgQTDmGGygi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a46ccd8abb326df79e8f1345',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a46ccd8abb326df79e8f1345',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a46ccd8abb326df79e8f1345',
#       'width': 64}],
#     'name': 'The Hearse',
#     'release_date': '2013-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:4mhzdJ2ILI1LgQTDmGGygi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39wovx5sCg0UkoTF7nBG2X'},
#      'href': 'https://api.spotify.com/v1/artists/39wovx5sCg0UkoTF7nBG2X',
#      'id': '39wovx5sCg0UkoTF7nBG2X',
#      'name': 'Wampire',
#      'type': 'artist',
#      'uri': 'spotify:artist:39wovx5sCg0UkoTF7nBG2X'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 280106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US3R41325701'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1JGXx7CG3CxUYmuaNLyuQ3'},
#    'href': 'https://api.spotify.com/v1/tracks/1JGXx7CG3CxUYmuaNLyuQ3',
#    'id': '1JGXx7CG3CxUYmuaNLyuQ3',
#    'is_local': False,
#    'name': 'The Hearse',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1JGXx7CG3CxUYmuaNLyuQ3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QgSmABpItIdj908ek80n5'},
#       'href': 'https://api.spotify.com/v1/artists/3QgSmABpItIdj908ek80n5',
#       'id': '3QgSmABpItIdj908ek80n5',
#       'name': 'Morphine',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QgSmABpItIdj908ek80n5'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FocpOyE7RnaNsiaEhSbp6'},
#     'href': 'https://api.spotify.com/v1/albums/0FocpOyE7RnaNsiaEhSbp6',
#     'id': '0FocpOyE7RnaNsiaEhSbp6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b0f39b11297dc844ed04c36a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b0f39b11297dc844ed04c36a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b0f39b11297dc844ed04c36a',
#       'width': 64}],
#     'name': 'Cure for Pain',
#     'release_date': '1993-09-14',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0FocpOyE7RnaNsiaEhSbp6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QgSmABpItIdj908ek80n5'},
#      'href': 'https://api.spotify.com/v1/artists/3QgSmABpItIdj908ek80n5',
#      'id': '3QgSmABpItIdj908ek80n5',
#      'name': 'Morphine',
#      'type': 'artist',
#      'uri': 'spotify:artist:3QgSmABpItIdj908ek80n5'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 199666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRY10262002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2SSBJhvMsujY94GK5JAtKs'},
#    'href': 'https://api.spotify.com/v1/tracks/2SSBJhvMsujY94GK5JAtKs',
#    'id': '2SSBJhvMsujY94GK5JAtKs',
#    'is_local': False,
#    'name': 'Buena',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f2ab48e8b32af961c27431173358453b55c30f1b?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2SSBJhvMsujY94GK5JAtKs'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2014-06-20T16:10:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/massivemusic.com'},
#    'href': 'https://api.spotify.com/v1/users/massivemusic.com',
#    'id': 'massivemusic.com',
#    'type': 'user',
#    'uri': 'spotify:user:massivemusic.com'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WoeMzXhDQyoFCKdji4FlL'},
#       'href': 'https://api.spotify.com/v1/artists/4WoeMzXhDQyoFCKdji4FlL',
#       'id': '4WoeMzXhDQyoFCKdji4FlL',
#       'name': 'Amp Live',
#       'type': 'artist',
#       'uri': 'spotify:artist:4WoeMzXhDQyoFCKdji4FlL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/27pXB0rSC5c2xRCQgaibOy'},
#     'href': 'https://api.spotify.com/v1/albums/27pXB0rSC5c2xRCQgaibOy',
#     'id': '27pXB0rSC5c2xRCQgaibOy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734b43321704101cafb79d2492',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024b43321704101cafb79d2492',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514b43321704101cafb79d2492',
#       'width': 64}],
#     'name': 'Kaleidoscope Theory EP',
#     'release_date': '2012',
#     'release_date_precision': 'year',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:27pXB0rSC5c2xRCQgaibOy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WoeMzXhDQyoFCKdji4FlL'},
#      'href': 'https://api.spotify.com/v1/artists/4WoeMzXhDQyoFCKdji4FlL',
#      'id': '4WoeMzXhDQyoFCKdji4FlL',
#      'name': 'Amp Live',
#      'type': 'artist',
#      'uri': 'spotify:artist:4WoeMzXhDQyoFCKdji4FlL'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 286756,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USPG21200181'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7azrHbFNpxZNncn9BXpaW1'},
#    'href': 'https://api.spotify.com/v1/tracks/7azrHbFNpxZNncn9BXpaW1',
#    'id': '7azrHbFNpxZNncn9BXpaW1',
#    'is_local': False,
#    'name': 'D.H.E.A.',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/da062303fe0254fb0ea71d8429446443f62d0bff?cid=6617ca02c3ad4b0385d0a709c971d4f4',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:7azrHbFNpxZNncn9BXpaW1'},
#   'video_thumbnail': {'url': None}}]

# %%
len(playlist["items"])
# Out:
# 100

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks(play_list_id)
len(all_tracks)
# Out:
# 10000

# %%
tracks = json_normalize(all_tracks)

# %%
tracks.head()
# Out:
#                added_at  is_local primary_color  ... track.type                             track.uri video_thumbnail.url
# 0  2021-11-26T09:03:43Z     False          None  ...      track  spotify:track:6uDlwsguxFDgbakvPyhChp                None
# 1  2014-06-20T16:10:54Z     False          None  ...      track  spotify:track:00LvjMnpznr4MZFSA8x9sA                None
# 2  2014-06-20T16:10:54Z     False          None  ...      track  spotify:track:3E8gEvhLia6w9lQv3hfxzM                None
# 3  2014-06-20T16:10:54Z     False          None  ...      track  spotify:track:2jjPlj6KFzCffJ7KVQMwHX                None
# 4  2016-10-27T09:04:03Z     False          None  ...      track  spotify:track:3seHx466iTcUmWE9dOVB3v                None
#
# [5 rows x 40 columns]

# %%
# we can even create a new column containing these DataFrames! KEEP song URI
# NOTE: need to change this function, since the columns names are now a bit different
def expand_list_dict2(row):
    df = json_normalize(row['track.artists'])
    df['song_id'] = row['track.id']
    return df

tracks['artists_dfs'] = tracks.apply(expand_list_dict2, axis=1)
tracks['artists_dfs'][1]
# Out:
#                                                 href  ...                 song_id
# 0  https://api.spotify.com/v1/artists/63GCe948jqV...  ...  00LvjMnpznr4MZFSA8x9sA
# 1  https://api.spotify.com/v1/artists/2EMmqQQmszs...  ...  00LvjMnpznr4MZFSA8x9sA
# 2  https://api.spotify.com/v1/artists/1mM65AjhdrT...  ...  00LvjMnpznr4MZFSA8x9sA
# 3  https://api.spotify.com/v1/artists/0CJDBEjJQYG...  ...  00LvjMnpznr4MZFSA8x9sA
#
# [4 rows x 7 columns]

# %%
# now we create a new dataframe with all these artists
artist_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df in tracks['artists_dfs']:
    #display(val)
    artist_df = pd.concat([artist_df, mini_df], axis=0)
    
artist_df
# Out:
#                                                  href  ...                 song_id
# 0   https://api.spotify.com/v1/artists/7abqAQhqbQV...  ...  6uDlwsguxFDgbakvPyhChp
# 0   https://api.spotify.com/v1/artists/63GCe948jqV...  ...  00LvjMnpznr4MZFSA8x9sA
# 1   https://api.spotify.com/v1/artists/2EMmqQQmszs...  ...  00LvjMnpznr4MZFSA8x9sA
# 2   https://api.spotify.com/v1/artists/1mM65AjhdrT...  ...  00LvjMnpznr4MZFSA8x9sA
# 3   https://api.spotify.com/v1/artists/0CJDBEjJQYG...  ...  00LvjMnpznr4MZFSA8x9sA
# ..                                                ...  ...                     ...
# 0   https://api.spotify.com/v1/artists/2I36EjIVz3v...  ...  1PNaGC2ihDmVCldSce119E
# 1   https://api.spotify.com/v1/artists/1stlWvYSCm3...  ...  1PNaGC2ihDmVCldSce119E
# 2   https://api.spotify.com/v1/artists/5N6EzjkOoyA...  ...  1PNaGC2ihDmVCldSce119E
# 0   https://api.spotify.com/v1/artists/2oofDquWt9t...  ...  2887tlqmjY4WcyQ3Dy6dZy
# 0   https://api.spotify.com/v1/artists/0KxXd4a8NWQ...  ...  5xPYheD4STE2K5o6ff9WJK
#
# [11842 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged = pd.merge(left=tracks,
                    right=artist_df,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged.head()
# Out:
#                added_at  is_local  ...                              external_urls.spotify                 song_id
# 0  2021-11-26T09:03:43Z     False  ...  https://open.spotify.com/artist/7abqAQhqbQVO2W...  6uDlwsguxFDgbakvPyhChp
# 1  2014-06-20T16:10:54Z     False  ...  https://open.spotify.com/artist/63GCe948jqVvNv...  00LvjMnpznr4MZFSA8x9sA
# 2  2014-06-20T16:10:54Z     False  ...  https://open.spotify.com/artist/2EMmqQQmszsCXf...  00LvjMnpznr4MZFSA8x9sA
# 3  2014-06-20T16:10:54Z     False  ...  https://open.spotify.com/artist/1mM65AjhdrTa1e...  00LvjMnpznr4MZFSA8x9sA
# 4  2014-06-20T16:10:54Z     False  ...  https://open.spotify.com/artist/0CJDBEjJQYGcyC...  00LvjMnpznr4MZFSA8x9sA
#
# [5 rows x 48 columns]

# %%
df_merged.shape
# Out:
# (11846, 48)

# %%
df_final = df_merged[['track.name', 'name', 'song_id']]

# %% [markdown]
# ### Audio features

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]
# chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 11846

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True) # duplicates because some songs have more artists
len(audio_features_df)
# Out:
# 9998

# %%
df_w_audio_ft = pd.merge(left=df_final,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                                  track.name            name  ... duration_ms  time_signature
# 0      This Magic Moment - Crisp.nl Version    MassiveMusic  ...      188697               4
# 1                                     00h00          Hoosky  ...       51373               4
# 2                                     00h00  La Fine Equipe  ...       51373               4
# 3                                     00h00            oOgo  ...       51373               4
# 4                                     00h00         Chomsk'  ...       51373               4
# ...                                     ...             ...  ...         ...             ...
# 11841        Take It Slow - Mousse T. Remix    Boozoo Bajou  ...      216601               4
# 11842        Take It Slow - Mousse T. Remix       Joe Dukie  ...      216601               4
# 11843        Take It Slow - Mousse T. Remix       Mousse T.  ...      216601               4
# 11844                    Birds of a Feather           Mocky  ...      274013               4
# 11845                        Freeway (2006)     Earl Elliot  ...      146467               4
#
# [11846 rows x 21 columns]
